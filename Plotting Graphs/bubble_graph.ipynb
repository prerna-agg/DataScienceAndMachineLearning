# %%
import matplotlib.pyplot as plt

# %%
# In bubble charts the size of the bubble signify something

# %%
year=[2012,2013,2014,2015,2016,2017]
salary=[12,13,14,17,19,20]
population=[100,120,180,250,300,370]

# %%
plt.scatter(year,salary)
plt.show()

# %%
# In bubble you can give size of the points
plt.scatter(year,salary,s=population,c="r") # c can also have an array of same dimension as value, then each point can have color corresponding to the value present at index in the array ["blue","red","green"]
plt.title('Bubble Chart')
plt.show()

# %%
plt.scatter(year,salary,s=population,c="r",alpha=0.5) # by default alpha is 1, alpha sets the opacity of points
plt.title('Bubble Chart')
plt.show()

# %%
import numpy as np 
c=np.arange(len(year)) #  Stop is len(year), start is 0, and step is 1!
c[1]=c[0]

# %%
plt.scatter(year,salary,s=population,c=c,alpha=0.5)
plt.title('Bubble Chart')
plt.show()

# %%
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolors="b") #by default edge color wassame as the color of bubble but now its blue
plt.title('Bubble Chart')
plt.show()

# %%
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolors='b',marker='^') 
plt.title('Bubble Chart')
plt.show()

# %%
# in case you want to right text near points , its not that straight forward so we have to use plt.text()
plt.scatter(year,salary,s=population,c=c,alpha=0.5,edgecolors='b',marker='^') 
plt.title('Bubble Chart')
plt.text(year[0]+0.1,salary[0]+0.5,population[0])
plt.text(year[4]+0.1,salary[4]+0.5,population[4])
plt.show()
